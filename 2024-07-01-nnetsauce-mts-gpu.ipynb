# %%
# !pip install nnetsauce
# Out:
# Collecting nnetsauce
#   Downloading nnetsauce-0.22.4-py2.py3-none-any.whl.metadata (822 bytes)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nnetsauce) (1.4.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from nnetsauce) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from nnetsauce) (1.26.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from nnetsauce) (2.2.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from nnetsauce) (2.32.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from nnetsauce) (1.11.4)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from nnetsauce) (1.2.2)
# Requirement already satisfied: threadpoolctl in /opt/conda/lib/python3.10/site-packages (from nnetsauce) (3.2.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nnetsauce) (4.66.4)
# Requirement already satisfied: jax in /opt/conda/lib/python3.10/site-packages (from nnetsauce) (0.4.26)
# Requirement already satisfied: jaxlib in /opt/conda/lib/python3.10/site-packages (from nnetsauce) (0.4.26.dev20240504)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from jax->nnetsauce) (0.2.0)
# Requirement already satisfied: opt-einsum in /opt/conda/lib/python3.10/site-packages (from jax->nnetsauce) (3.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->nnetsauce) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->nnetsauce) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->nnetsauce) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->nnetsauce) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->nnetsauce) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->nnetsauce) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->nnetsauce) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->nnetsauce) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->nnetsauce) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->nnetsauce) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->nnetsauce) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->nnetsauce) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->nnetsauce) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->nnetsauce) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->nnetsauce) (1.16.0)
# Downloading nnetsauce-0.22.4-py2.py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 kB 3.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: nnetsauce
# Successfully installed nnetsauce-0.22.4

# %%
# !pip install git+https://github.com/Techtonique/mlsauce.git --verbose
# Out:
# Using pip 23.3.2 from /opt/conda/lib/python3.10/site-packages/pip (python 3.10)
# Collecting git+https://github.com/Techtonique/mlsauce.git
#   Cloning https://github.com/Techtonique/mlsauce.git to /tmp/pip-req-build-4jki394q
#   Running command git version
#   git version 2.25.1
#   Running command git clone --filter=blob:none https://github.com/Techtonique/mlsauce.git /tmp/pip-req-build-4jki394q
#   Cloning into '/tmp/pip-req-build-4jki394q'...
#   Running command git rev-parse HEAD
#   186e88974b95a139d0c1cea983b22989e7d7d6df
#   Resolved https://github.com/Techtonique/mlsauce.git to commit 186e88974b95a139d0c1cea983b22989e7d7d6df
#   Running command git rev-parse HEAD
#   186e88974b95a139d0c1cea983b22989e7d7d6df
#   Running command python setup.py egg_info
#   Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (1.26.4)
#   Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (1.11.4)
#   Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /opt/conda/lib/python3.10/site-packages (from scipy) (1.26.4)
#   Requirement already satisfied: Cython in /opt/conda/lib/python3.10/site-packages (3.0.8)
#   Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (2.32.3)
#   Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests) (3.3.2)
#   Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests) (3.6)
#   Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests) (1.26.18)
#   Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests) (2024.2.2)
#   /opt/conda/lib/python3.10/site-packages/Cython/Compiler/Main.py:381: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: /tmp/pip-req-build-4jki394q/mlsauce/adaopt/_adaoptc.pyx
#     tree = Parsing.p_module(s, pxd, full_module_name)
#   /opt/conda/lib/python3.10/site-packages/Cython/Compiler/Main.py:381: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: /tmp/pip-req-build-4jki394q/mlsauce/booster/_boosterc.pyx
#     tree = Parsing.p_module(s, pxd, full_module_name)
#   /opt/conda/lib/python3.10/site-packages/Cython/Compiler/Main.py:381: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: /tmp/pip-req-build-4jki394q/mlsauce/lasso/_lassoc.pyx
#     tree = Parsing.p_module(s, pxd, full_module_name)
#   warning: mlsauce/lasso/_lassoc.pyx:213:40: the result of using negative indices inside of code sections marked as 'wraparound=False' is undefined
#   warning: mlsauce/lasso/_lassoc.pyx:219:42: the result of using negative indices inside of code sections marked as 'wraparound=False' is undefined
#   warning: mlsauce/lasso/_lassoc.pyx:221:41: the result of using negative indices inside of code sections marked as 'wraparound=False' is undefined
#   /opt/conda/lib/python3.10/site-packages/Cython/Compiler/Main.py:381: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: /tmp/pip-req-build-4jki394q/mlsauce/ridge/_ridgec.pyx
#     tree = Parsing.p_module(s, pxd, full_module_name)
#   warning: mlsauce/ridge/_ridgec.pyx:146:40: the result of using negative indices inside of code sections marked as 'wraparound=False' is undefined
#   warning: mlsauce/ridge/_ridgec.pyx:152:42: the result of using negative indices inside of code sections marked as 'wraparound=False' is undefined
#   warning: mlsauce/ridge/_ridgec.pyx:154:41: the result of using negative indices inside of code sections marked as 'wraparound=False' is undefined
#   /opt/conda/lib/python3.10/site-packages/Cython/Compiler/Main.py:381: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: /tmp/pip-req-build-4jki394q/mlsauce/stump/_stumpc.pyx
#     tree = Parsing.p_module(s, pxd, full_module_name)
#   Compiling mlsauce/adaopt/_adaoptc.pyx because it changed.
#   Compiling mlsauce/booster/_boosterc.pyx because it changed.
#   Compiling mlsauce/lasso/_lassoc.pyx because it changed.
#   Compiling mlsauce/ridge/_ridgec.pyx because it changed.
#   Compiling mlsauce/stump/_stumpc.pyx because it changed.
#   [1/5] Cythonizing mlsauce/adaopt/_adaoptc.pyx
#   [2/5] Cythonizing mlsauce/booster/_boosterc.pyx
#   [3/5] Cythonizing mlsauce/lasso/_lassoc.pyx
#   [4/5] Cythonizing mlsauce/ridge/_ridgec.pyx
#   [5/5] Cythonizing mlsauce/stump/_stumpc.pyx
#   /opt/conda/lib/python3.10/site-packages/setuptools/__init__.py:80: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#   !!
#
#           ********************************************************************************
#           Requirements should be satisfied by a PEP 517 installer.
#           If you are using pip, you can try `pip install --use-pep517`.
#           ********************************************************************************
#
#   !!
#     dist.fetch_build_eggs(dist.setup_requires)
#   /tmp/pip-req-build-4jki394q/mlsauce/adaopt/_adaoptc.c:1220:10: fatal error: numpy/arrayobject.h: No such file or directory
#    1220 | #include "numpy/arrayobject.h"
#         |          ^~~~~~~~~~~~~~~~~~~~~
#   compilation terminated.
#   error: command '/usr/bin/gcc' failed with exit code 1
#   /tmp/pip-req-build-4jki394q/mlsauce/booster/_boosterc.c:1220:10: fatal error: numpy/arrayobject.h: No such file or directory
#    1220 | #include "numpy/arrayobject.h"
#         |          ^~~~~~~~~~~~~~~~~~~~~
#   compilation terminated.
#   error: command '/usr/bin/gcc' failed with exit code 1
#   python3: can't open file '/tmp/pip-req-build-4jki394q/mlsauce/elasticnet/setup2.py': [Errno 2] No such file or directory
#   /tmp/pip-req-build-4jki394q/mlsauce/lasso/_lassoc.c:1220:10: fatal error: numpy/arrayobject.h: No such file or directory
#    1220 | #include "numpy/arrayobject.h"
#         |          ^~~~~~~~~~~~~~~~~~~~~
#   compilation terminated.
#   error: command '/usr/bin/gcc' failed with exit code 1
#   /tmp/pip-req-build-4jki394q/mlsauce/ridge/_ridgec.c:1220:10: fatal error: numpy/arrayobject.h: No such file or directory
#    1220 | #include "numpy/arrayobject.h"
#         |          ^~~~~~~~~~~~~~~~~~~~~
#   compilation terminated.
#   error: command '/usr/bin/gcc' failed with exit code 1
#   /tmp/pip-req-build-4jki394q/mlsauce/stump/_stumpc.c:1220:10: fatal error: numpy/arrayobject.h: No such file or directory
#    1220 | #include "numpy/arrayobject.h"
#         |          ^~~~~~~~~~~~~~~~~~~~~
#   compilation terminated.
#   error: command '/usr/bin/gcc' failed with exit code 1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from mlsauce==0.18.4) (1.26.4)
# Requirement already satisfied: Cython in /opt/conda/lib/python3.10/site-packages (from mlsauce==0.18.4) (3.0.8)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from mlsauce==0.18.4) (1.4.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mlsauce==0.18.4) (3.7.5)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from mlsauce==0.18.4) (2.2.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from mlsauce==0.18.4) (2.32.3)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from mlsauce==0.18.4) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from mlsauce==0.18.4) (1.11.4)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from mlsauce==0.18.4) (4.66.4)
# Requirement already satisfied: jax in /opt/conda/lib/python3.10/site-packages (from mlsauce==0.18.4) (0.4.26)
# Requirement already satisfied: jaxlib in /opt/conda/lib/python3.10/site-packages (from mlsauce==0.18.4) (0.4.26.dev20240504)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from jax->mlsauce==0.18.4) (0.2.0)
# Requirement already satisfied: opt-einsum in /opt/conda/lib/python3.10/site-packages (from jax->mlsauce==0.18.4) (3.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mlsauce==0.18.4) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mlsauce==0.18.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mlsauce==0.18.4) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mlsauce==0.18.4) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mlsauce==0.18.4) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mlsauce==0.18.4) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mlsauce==0.18.4) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mlsauce==0.18.4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->mlsauce==0.18.4) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->mlsauce==0.18.4) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->mlsauce==0.18.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->mlsauce==0.18.4) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->mlsauce==0.18.4) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->mlsauce==0.18.4) (2024.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->mlsauce==0.18.4) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mlsauce==0.18.4) (1.16.0)
# Building wheels for collected packages: mlsauce
#   Running command python setup.py bdist_wheel
#   Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (1.26.4)
#   Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (1.11.4)
#   Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /opt/conda/lib/python3.10/site-packages (from scipy) (1.26.4)
#   Requirement already satisfied: Cython in /opt/conda/lib/python3.10/site-packages (3.0.8)
#   Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (2.32.3)
#   Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests) (3.3.2)
#   Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests) (3.6)
#   Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests) (1.26.18)
#   Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests) (2024.2.2)
#   /opt/conda/lib/python3.10/site-packages/setuptools/__init__.py:80: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#   !!
#
#           ********************************************************************************
#           Requirements should be satisfied by a PEP 517 installer.
#           If you are using pip, you can try `pip install --use-pep517`.
#           ********************************************************************************
#
#   !!
#     dist.fetch_build_eggs(dist.setup_requires)
#   /opt/conda/lib/python3.10/site-packages/setuptools/command/build_py.py:207: _Warning: Package 'mlsauce.demo' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'mlsauce.demo' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'mlsauce.demo' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'mlsauce.demo' to be distributed and are
#           already explicitly excluding 'mlsauce.demo' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   In file included from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                    from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                    from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                    from mlsauce/adaopt/_adaoptc.c:1220:
#   /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#      17 | #warning "Using deprecated NumPy API, disable it with " \
#         |  ^~~~~~~
#   In file included from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                    from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                    from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                    from mlsauce/booster/_boosterc.c:1220:
#   /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#      17 | #warning "Using deprecated NumPy API, disable it with " \
#         |  ^~~~~~~
#   In file included from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                    from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                    from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                    from mlsauce/lasso/_lassoc.c:1220:
#   /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#      17 | #warning "Using deprecated NumPy API, disable it with " \
#         |  ^~~~~~~
#   In file included from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                    from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                    from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                    from mlsauce/ridge/_ridgec.c:1220:
#   /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#      17 | #warning "Using deprecated NumPy API, disable it with " \
#         |  ^~~~~~~
#   In file included from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                    from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                    from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                    from mlsauce/stump/_stumpc.c:1220:
#   /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#      17 | #warning "Using deprecated NumPy API, disable it with " \
#         |  ^~~~~~~
#   mlsauce/stump/_stumpc.c:19657:15: warning: '__pyx_f_7mlsauce_5stump_7_stumpc_max_c' defined but not used [-Wunused-function]
#   19657 | static double __pyx_f_7mlsauce_5stump_7_stumpc_max_c(double __pyx_v_x, double __pyx_v_y) {
#         |               ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   mlsauce/stump/_stumpc.c:19593:15: warning: '__pyx_f_7mlsauce_5stump_7_stumpc_min_c' defined but not used [-Wunused-function]
#   19593 | static double __pyx_f_7mlsauce_5stump_7_stumpc_min_c(double __pyx_v_x, double __pyx_v_y) {
#         |               ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   mlsauce/stump/_stumpc.c: In function '__pyx_pw_7mlsauce_5stump_7_stumpc_5fit_stump_classifier':
#   mlsauce/stump/_stumpc.c:1122:40: warning: '__pyx_v_best_class' may be used uninitialized in this function [-Wmaybe-uninitialized]
#    1122 |   #define PyInt_FromLong               PyLong_FromLong
#         |                                        ^~~~~~~~~~~~~~~
#   mlsauce/stump/_stumpc.c:20747:7: note: '__pyx_v_best_class' was declared here
#   20747 |   int __pyx_v_best_class;
#         |       ^~~~~~~~~~~~~~~~~~
#   mlsauce/stump/_stumpc.c:1122:40: warning: '__pyx_v_best_col' may be used uninitialized in this function [-Wmaybe-uninitialized]
#    1122 |   #define PyInt_FromLong               PyLong_FromLong
#         |                                        ^~~~~~~~~~~~~~~
#   mlsauce/stump/_stumpc.c:20740:7: note: '__pyx_v_best_col' was declared here
#   20740 |   int __pyx_v_best_col;
#         |       ^~~~~~~~~~~~~~~~
#   /opt/conda/lib/python3.10/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#   !!
#
#           ********************************************************************************
#           Please avoid running ``setup.py`` directly.
#           Instead, use pypa/build, pypa/installer or other
#           standards-based tools.
#
#           See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#           ********************************************************************************
#
#   !!
#     self.initialize_options()
#   python3: can't open file '/tmp/pip-req-build-4jki394q/mlsauce/elasticnet/setup2.py': [Errno 2] No such file or directory
#   Building wheel for mlsauce (setup.py) ... done
#   Created wheel for mlsauce: filename=mlsauce-0.18.4-cp310-cp310-linux_x86_64.whl size=3683257 sha256=a23dc9537c22fbedd7ba778d74337b8e96745e173a00d219531366bfbe2ac280
#   Stored in directory: /tmp/pip-ephem-wheel-cache-d98ov6gm/wheels/3e/e7/ed/dce5183649530d16a5a118832f4d79e58c5351bfec7f553c93
# Successfully built mlsauce
# Installing collected packages: mlsauce
# Successfully installed mlsauce-0.18.4

# %%
import numpy as np
import pandas as pd
import mlsauce as ms 
import nnetsauce as ns
from sklearn.linear_model import Ridge 
from time import time

# %%
def generate_synthetic_mts(n_steps=1000, n_series=3, frequency=24, amplitude=20, base_noise_std=5, volatility_increase_rate=0.01, seed=42):
    """
    Generate a synthetic multivariate time series with random trends, seasonality, and one series with increasing volatility.

    Parameters:
    - n_steps: Number of time steps
    - n_series: Number of series
    - frequency: Frequency of the seasonal component
    - amplitude: Amplitude of the seasonal component
    - base_noise_std: Base standard deviation of the noise
    - volatility_increase_rate: Rate at which the volatility increases for the first series
    - seed: Random seed for reproducibility

    Returns:
    - A pandas DataFrame containing the generated multivariate time series
    """
    np.random.seed(seed)

    # Define a dynamically generated correlation matrix
    correlation_matrix = np.ones((n_series, n_series))
    for i in range(n_series):
        for j in range(i+1, n_series):
            correlation_matrix[i, j] = correlation_matrix[j, i] = 0.8 ** abs(i - j)

    # Compute the covariance matrix from the correlation matrix
    noise_std = np.array([base_noise_std] * n_series)
    covariance_matrix = np.outer(noise_std, noise_std) * correlation_matrix

    # Create a time index
    time = np.arange(n_steps)

    # Initialize an empty array to store the time series data
    data = np.zeros((n_steps, n_series))

    # Generate correlated noise using multivariate normal distribution
    noise = np.random.multivariate_normal(np.zeros(n_series), covariance_matrix, n_steps)

    # Generate random slopes for the trends (including negative slopes) with a wider range
    slopes = np.random.uniform(low=-0.3, high=0.3, size=n_series)

    for i in range(n_series):
        # Trend component with a random slope (positive or negative)
        trend = slopes[i] * time

        # Seasonal component with increased amplitude
        seasonality = amplitude * np.sin(2 * np.pi * time / frequency + np.random.randn())

        if i == 0:
            # For the first series, increase the volatility over time
            increasing_noise = noise[:, i] * (1 + volatility_increase_rate * time)
            data[:, i] = trend + seasonality + increasing_noise
        else:
            # For other series, use constant volatility
            data[:, i] = trend + seasonality + noise[:, i]

    # Combine into a multivariate time series dataset
    df = pd.DataFrame(data, columns=[f'Series_{i+1}' for i in range(n_series)], index=pd.date_range(start='2023-01-01', periods=n_steps))

    return df

# %%
df = generate_synthetic_mts(n_steps=10000, n_series=100, 
                            amplitude=40, seed=14531)
df_ = df.diff().dropna()

# Display the first few rows of the dataset
print(df_.head())
# Out:
#             Series_1  Series_2  Series_3  Series_4  Series_5  Series_6  \
# 2023-01-02     22.41     15.56     19.87      6.56     10.82     12.09
# 2023-01-03      7.10     -1.53      1.20      1.53     -1.22      7.75
# 2023-01-04     -2.44      3.53      8.63      6.06      2.85      7.64
# 2023-01-05     20.46     23.78     19.72     14.81      2.72     14.96
# 2023-01-06     10.06     11.02      7.73     12.76     -4.89      4.61
#
#             Series_7  Series_8  Series_9  Series_10  ...  Series_91  \
# 2023-01-02     10.25     10.39     -3.30       2.23  ...      13.68
# 2023-01-03     -0.03      9.96     -3.55      11.30  ...     -10.46
# 2023-01-04      0.22      2.45     -4.71      10.50  ...       9.18
# 2023-01-05      2.57     18.55      6.58       3.43  ...      -6.99
# 2023-01-06     -5.07      2.47      8.14       5.50  ...       7.88
#
#             Series_92  Series_93  Series_94  Series_95  Series_96  Series_97  \
# 2023-01-02      13.66       7.86      10.00      13.53      -2.50      14.86
# 2023-01-03      -7.64     -13.23       5.41       8.05      -9.36       3.00
# 2023-01-04      13.91       4.26      12.79       8.83     -15.13       4.67
# 2023-01-05      10.02      -7.26       6.76       3.40      -8.33      -3.27
# 2023-01-06      25.44       4.55      24.32      24.47       6.32       6.91
#
#             Series_98  Series_99  Series_100
# 2023-01-02      11.15       7.60       18.72
# 2023-01-03       3.53      13.20        8.39
# 2023-01-04      -5.43      -1.46       -0.40
# 2023-01-05       0.21      16.34       15.03
# 2023-01-06      11.56      23.95       23.61
#
# [5 rows x 100 columns]

# %% [markdown]
# # Example 1

# %%
regr = Ridge()
obj_MTS = ns.MTS(regr,
                 lags = 15,
                 n_hidden_features=5,
                 nodes_sim="uniform",
                 backend="cpu",
                 verbose = 1)
start = time()
obj_MTS.fit(df_)
print(f"Elapsed: {time()-start}")
# Out:
#  Adjusting Ridge to multivariate time series...
# 100%|██████████| 100/100 [01:01<00:00,  1.64it/s]
# Elapsed: 64.46652388572693

# %%
obj_MTS.predict(h=10)
# Out:
#             Series_1  Series_2  Series_3  Series_4  Series_5  Series_6  \
# date
# 2050-05-19   -797.65    -13.81     -9.29     -4.87      2.50    -11.09
# 2050-05-20     88.26     -7.44     -5.85     -8.67      8.85     -4.90
# 2050-05-21    -10.57    -11.58     -3.10     -8.14     10.25      1.95
# 2050-05-22    186.03     -6.36     -4.62    -10.75      9.38     -4.28
# 2050-05-23   -100.65    -10.53     -3.16    -12.82      4.83     -3.21
# 2050-05-24     76.41     -4.12      3.56     -6.82     12.27      6.40
# 2050-05-25   -149.78     -5.34      1.71     -8.29      8.03      5.15
# 2050-05-26    128.25      2.22     10.43     -1.04     12.37     11.20
# 2050-05-27    -28.48      3.37      6.69     -3.19      5.74      8.62
# 2050-05-28     47.37      4.66     10.35      2.85      6.07      9.97
#
#             Series_7  Series_8  Series_9  Series_10  ...  Series_91  \
# date                                                 ...
# 2050-05-19      2.92     -5.26      2.17      -2.35  ...       7.38
# 2050-05-20      3.93     -6.39     -8.37      -6.60  ...       2.75
# 2050-05-21     10.30      0.67     -2.69       3.19  ...       9.92
# 2050-05-22      4.69     -6.67    -12.60      -2.92  ...       2.95
# 2050-05-23      4.90      0.56    -12.42       1.26  ...      19.08
# 2050-05-24     15.32      6.56     -7.21       7.37  ...       9.88
# 2050-05-25      8.61      6.20     -8.67       7.72  ...       6.22
# 2050-05-26     10.19      6.58     -9.45       9.95  ...       7.31
# 2050-05-27      8.46     11.76     -5.10       8.82  ...       4.53
# 2050-05-28      4.88      9.06     -4.90      10.49  ...       7.30
#
#             Series_92  Series_93  Series_94  Series_95  Series_96  Series_97  \
# date
# 2050-05-19      -6.08       8.95      -7.32      -2.45      13.57       1.21
# 2050-05-20     -12.73       4.06     -12.97      -9.14       6.50      -1.08
# 2050-05-21     -10.34       7.50      -8.28      -2.51      10.83       5.20
# 2050-05-22     -13.98       5.65     -11.96      -6.58       2.93       2.96
# 2050-05-23      -0.73      19.08       6.20       9.01       7.70      11.79
# 2050-05-24      -5.64       8.56      -3.25       3.11       1.55       7.41
# 2050-05-25      -6.31       7.98       2.23       6.48       2.26      13.24
# 2050-05-26      -0.61       7.22       3.90       8.66      -5.34       7.73
# 2050-05-27      -0.26       1.14       4.82       8.12      -8.39       8.09
# 2050-05-28       5.92       2.87       9.31      12.60      -7.18       7.94
#
#             Series_98  Series_99  Series_100
# date
# 2050-05-19       2.46      -5.99       -1.13
# 2050-05-20       2.63     -13.85      -12.23
# 2050-05-21       9.45      -5.04       -3.51
# 2050-05-22       5.43     -10.36       -6.82
# 2050-05-23      10.60      -2.16       -1.75
# 2050-05-24       8.39      -3.89       -1.11
# 2050-05-25      13.69       3.61        8.75
# 2050-05-26       7.96       3.92        4.80
# 2050-05-27       6.49       4.11        5.14
# 2050-05-28       5.57       8.74        9.76
#
# [10 rows x 100 columns]

# %%
regr = Ridge()
obj_MTS = ns.MTS(regr,
                 lags = 15,
                 n_hidden_features=5,
                 nodes_sim="uniform",
                 backend="gpu",
                 verbose = 1)
start = time()
obj_MTS.fit(df_)
print(f"Elapsed: {time()-start}")
# Out:
#  Adjusting Ridge to multivariate time series...
# 100%|██████████| 100/100 [00:37<00:00,  2.68it/s]
# Elapsed: 40.53069853782654

# %%
obj_MTS.predict(h=10)
# Out:
#             Series_1  Series_2  Series_3  Series_4  Series_5  Series_6  \
# date
# 2050-05-19   -797.73    -13.81     -9.29     -4.87      2.50    -11.09
# 2050-05-20     88.37     -7.44     -5.85     -8.67      8.85     -4.90
# 2050-05-21    -10.64    -11.59     -3.11     -8.14     10.25      1.95
# 2050-05-22    186.01     -6.36     -4.62    -10.75      9.38     -4.28
# 2050-05-23   -100.54    -10.53     -3.16    -12.82      4.83     -3.21
# 2050-05-24     76.34     -4.12      3.56     -6.82     12.27      6.40
# 2050-05-25   -149.74     -5.34      1.71     -8.29      8.03      5.15
# 2050-05-26    128.23      2.22     10.43     -1.04     12.37     11.20
# 2050-05-27    -28.48      3.37      6.70     -3.19      5.74      8.62
# 2050-05-28     47.37      4.66     10.34      2.85      6.07      9.97
#
#             Series_7  Series_8  Series_9  Series_10  ...  Series_91  \
# date                                                 ...
# 2050-05-19      2.92     -5.26      2.16      -2.35  ...       7.38
# 2050-05-20      3.93     -6.39     -8.37      -6.60  ...       2.75
# 2050-05-21     10.30      0.66     -2.69       3.19  ...       9.92
# 2050-05-22      4.69     -6.67    -12.60      -2.92  ...       2.95
# 2050-05-23      4.90      0.56    -12.42       1.25  ...      19.09
# 2050-05-24     15.32      6.56     -7.21       7.36  ...       9.88
# 2050-05-25      8.61      6.20     -8.67       7.72  ...       6.22
# 2050-05-26     10.18      6.58     -9.45       9.95  ...       7.31
# 2050-05-27      8.46     11.76     -5.10       8.82  ...       4.53
# 2050-05-28      4.88      9.06     -4.90      10.49  ...       7.30
#
#             Series_92  Series_93  Series_94  Series_95  Series_96  Series_97  \
# date
# 2050-05-19      -6.08       8.95      -7.32      -2.46      13.57       1.21
# 2050-05-20     -12.73       4.06     -12.97      -9.14       6.50      -1.08
# 2050-05-21     -10.34       7.50      -8.28      -2.50      10.83       5.20
# 2050-05-22     -13.99       5.65     -11.96      -6.58       2.93       2.96
# 2050-05-23      -0.73      19.08       6.21       9.01       7.70      11.79
# 2050-05-24      -5.64       8.56      -3.25       3.11       1.55       7.41
# 2050-05-25      -6.31       7.98       2.23       6.48       2.26      13.24
# 2050-05-26      -0.61       7.22       3.90       8.66      -5.34       7.73
# 2050-05-27      -0.26       1.14       4.82       8.12      -8.39       8.09
# 2050-05-28       5.92       2.87       9.31      12.60      -7.18       7.94
#
#             Series_98  Series_99  Series_100
# date
# 2050-05-19       2.46      -5.99       -1.13
# 2050-05-20       2.63     -13.85      -12.23
# 2050-05-21       9.45      -5.04       -3.51
# 2050-05-22       5.43     -10.36       -6.82
# 2050-05-23      10.61      -2.16       -1.75
# 2050-05-24       8.39      -3.89       -1.11
# 2050-05-25      13.69       3.61        8.75
# 2050-05-26       7.96       3.92        4.80
# 2050-05-27       6.49       4.11        5.14
# 2050-05-28       5.57       8.74        9.76
#
# [10 rows x 100 columns]

# %%
regr = ms.RidgeRegressor(reg_lambda=1.0, backend="cpu")
obj_MTS = ns.MTS(regr,
                 lags = 15,
                 n_hidden_features=5,
                 nodes_sim="uniform",
                 backend="gpu",
                 verbose = 1)
start = time()
obj_MTS.fit(df_)
print(f"Elapsed: {time()-start}")
# Out:
#  Adjusting RidgeRegressor to multivariate time series...
# 100%|██████████| 100/100 [01:13<00:00,  1.35it/s]
# Elapsed: 77.08472633361816

# %%
obj_MTS.predict(h=10)
# Out:
#             Series_1  Series_2  Series_3  Series_4  Series_5  Series_6  \
# date
# 2050-05-19   -797.65    -13.81     -9.29     -4.87      2.50    -11.09
# 2050-05-20     88.26     -7.44     -5.85     -8.67      8.85     -4.90
# 2050-05-21    -10.57    -11.58     -3.10     -8.14     10.25      1.95
# 2050-05-22    186.03     -6.36     -4.62    -10.75      9.38     -4.28
# 2050-05-23   -100.65    -10.53     -3.16    -12.82      4.83     -3.21
# 2050-05-24     76.41     -4.12      3.56     -6.82     12.27      6.40
# 2050-05-25   -149.78     -5.34      1.71     -8.29      8.03      5.15
# 2050-05-26    128.25      2.22     10.43     -1.04     12.37     11.20
# 2050-05-27    -28.48      3.37      6.69     -3.19      5.74      8.62
# 2050-05-28     47.37      4.66     10.35      2.85      6.07      9.97
#
#             Series_7  Series_8  Series_9  Series_10  ...  Series_91  \
# date                                                 ...
# 2050-05-19      2.92     -5.26      2.17      -2.35  ...       7.38
# 2050-05-20      3.93     -6.39     -8.37      -6.60  ...       2.75
# 2050-05-21     10.30      0.67     -2.69       3.19  ...       9.92
# 2050-05-22      4.69     -6.67    -12.60      -2.92  ...       2.95
# 2050-05-23      4.90      0.56    -12.42       1.26  ...      19.08
# 2050-05-24     15.32      6.56     -7.21       7.37  ...       9.88
# 2050-05-25      8.61      6.20     -8.67       7.72  ...       6.22
# 2050-05-26     10.19      6.58     -9.45       9.95  ...       7.31
# 2050-05-27      8.46     11.76     -5.10       8.82  ...       4.53
# 2050-05-28      4.88      9.06     -4.90      10.49  ...       7.30
#
#             Series_92  Series_93  Series_94  Series_95  Series_96  Series_97  \
# date
# 2050-05-19      -6.08       8.95      -7.32      -2.45      13.57       1.21
# 2050-05-20     -12.73       4.06     -12.97      -9.14       6.50      -1.08
# 2050-05-21     -10.34       7.50      -8.28      -2.51      10.83       5.20
# 2050-05-22     -13.98       5.65     -11.96      -6.58       2.93       2.96
# 2050-05-23      -0.73      19.08       6.20       9.01       7.70      11.79
# 2050-05-24      -5.64       8.56      -3.25       3.11       1.55       7.41
# 2050-05-25      -6.31       7.98       2.23       6.48       2.26      13.24
# 2050-05-26      -0.61       7.22       3.90       8.66      -5.34       7.73
# 2050-05-27      -0.26       1.14       4.82       8.12      -8.39       8.09
# 2050-05-28       5.92       2.87       9.31      12.60      -7.18       7.94
#
#             Series_98  Series_99  Series_100
# date
# 2050-05-19       2.46      -5.99       -1.13
# 2050-05-20       2.63     -13.85      -12.23
# 2050-05-21       9.45      -5.04       -3.51
# 2050-05-22       5.43     -10.36       -6.82
# 2050-05-23      10.60      -2.16       -1.75
# 2050-05-24       8.39      -3.89       -1.11
# 2050-05-25      13.69       3.61        8.75
# 2050-05-26       7.96       3.92        4.80
# 2050-05-27       6.49       4.11        5.14
# 2050-05-28       5.57       8.74        9.76
#
# [10 rows x 100 columns]

# %%
regr = ms.RidgeRegressor(reg_lambda=1.0, backend="gpu")
obj_MTS = ns.MTS(regr,
                 lags = 15,
                 n_hidden_features=5,
                 nodes_sim="uniform",
                 backend="gpu",
                 verbose = 1)
start = time()
obj_MTS.fit(df_)
print(f"Elapsed: {time()-start}")
# Out:
#  Adjusting RidgeRegressor to multivariate time series...
# 100%|██████████| 100/100 [00:20<00:00,  4.89it/s]
# Elapsed: 23.551459312438965

# %%
obj_MTS.predict(h=10)
# Out:
#             Series_1  Series_2  Series_3  Series_4  Series_5  Series_6  \
# date
# 2050-05-19   -797.68    -13.82     -9.29     -4.88      2.51    -11.09
# 2050-05-20     88.32     -7.44     -5.86     -8.67      8.84     -4.90
# 2050-05-21    -10.57    -11.59     -3.10     -8.15     10.26      1.96
# 2050-05-22    186.01     -6.36     -4.62    -10.74      9.37     -4.29
# 2050-05-23   -100.73    -10.54     -3.16    -12.83      4.84     -3.20
# 2050-05-24     76.47     -4.11      3.56     -6.81     12.27      6.40
# 2050-05-25   -149.91     -5.35      1.71     -8.29      8.02      5.14
# 2050-05-26    128.29      2.22     10.43     -1.04     12.37     11.20
# 2050-05-27    -28.41      3.37      6.70     -3.18      5.74      8.62
# 2050-05-28     47.62      4.66     10.35      2.85      6.08      9.98
#
#             Series_7  Series_8  Series_9  Series_10  ...  Series_91  \
# date                                                 ...
# 2050-05-19      2.92     -5.26      2.16      -2.35  ...       7.39
# 2050-05-20      3.93     -6.40     -8.36      -6.61  ...       2.75
# 2050-05-21     10.31      0.67     -2.69       3.19  ...       9.93
# 2050-05-22      4.68     -6.68    -12.59      -2.93  ...       2.94
# 2050-05-23      4.90      0.56    -12.43       1.26  ...      19.09
# 2050-05-24     15.32      6.56     -7.21       7.37  ...       9.87
# 2050-05-25      8.60      6.20     -8.67       7.71  ...       6.22
# 2050-05-26     10.19      6.58     -9.45       9.94  ...       7.31
# 2050-05-27      8.46     11.76     -5.10       8.82  ...       4.53
# 2050-05-28      4.89      9.06     -4.90      10.49  ...       7.30
#
#             Series_92  Series_93  Series_94  Series_95  Series_96  Series_97  \
# date
# 2050-05-19      -6.08       8.95      -7.32      -2.45      13.57       1.21
# 2050-05-20     -12.73       4.05     -12.97      -9.15       6.50      -1.09
# 2050-05-21     -10.34       7.50      -8.28      -2.50      10.83       5.21
# 2050-05-22     -13.98       5.64     -11.96      -6.58       2.93       2.95
# 2050-05-23      -0.73      19.09       6.21       9.01       7.70      11.80
# 2050-05-24      -5.63       8.56      -3.24       3.11       1.55       7.41
# 2050-05-25      -6.31       7.98       2.23       6.48       2.26      13.23
# 2050-05-26      -0.61       7.22       3.90       8.66      -5.34       7.73
# 2050-05-27      -0.26       1.13       4.83       8.12      -8.40       8.09
# 2050-05-28       5.92       2.87       9.32      12.61      -7.18       7.94
#
#             Series_98  Series_99  Series_100
# date
# 2050-05-19       2.47      -5.99       -1.13
# 2050-05-20       2.62     -13.85      -12.23
# 2050-05-21       9.46      -5.04       -3.50
# 2050-05-22       5.42     -10.37       -6.83
# 2050-05-23      10.62      -2.16       -1.75
# 2050-05-24       8.38      -3.89       -1.11
# 2050-05-25      13.69       3.62        8.75
# 2050-05-26       7.95       3.92        4.80
# 2050-05-27       6.49       4.11        5.14
# 2050-05-28       5.57       8.74        9.76
#
# [10 rows x 100 columns]

# %% [markdown]
# # Example 2

# %%
import xgboost as xgb 

xgb1 = xgb.XGBRegressor()
xgb2 = xgb.XGBRegressor(tree_method = "gpu_hist")

# %%
obj_MTS = ns.MTS(xgb1,
                 lags = 15,
                 n_hidden_features=5,
                 nodes_sim="uniform",
                 backend="cpu",
                 verbose = 1)
start = time()
obj_MTS.fit(df_)
print(f"Elapsed: {time()-start}")
# Out:
#  Adjusting XGBRegressor to multivariate time series...
# 100%|██████████| 100/100 [54:42<00:00, 32.82s/it]
# Elapsed: 3285.469851732254

# %%
obj_MTS = ns.MTS(xgb1,
                 lags = 15,
                 n_hidden_features=5,
                 nodes_sim="uniform",
                 backend="gpu",
                 verbose = 1)
start = time()
obj_MTS.fit(df_)
print(f"Elapsed: {time()-start}")
# Out:
#  Adjusting XGBRegressor to multivariate time series...
# 100%|██████████| 100/100 [54:23<00:00, 32.64s/it]
# Elapsed: 3266.556359767914

# %%
obj_MTS = ns.MTS(xgb2,
                 lags = 15,
                 n_hidden_features=5,
                 nodes_sim="uniform",
                 backend="cpu",
                 verbose = 1)
start = time()
obj_MTS.fit(df_)
print(f"Elapsed: {time()-start}")
# Out:
#  Adjusting XGBRegressor to multivariate time series...
# 100%|██████████| 100/100 [04:06<00:00,  2.46s/it]
# Elapsed: 249.40361714363098

# %%
obj_MTS = ns.MTS(xgb2,
                 lags = 15,
                 n_hidden_features=5,
                 nodes_sim="uniform",
                 backend="gpu",
                 verbose = 1)
start = time()
obj_MTS.fit(df_)
print(f"Elapsed: {time()-start}")
# Out:
#  Adjusting XGBRegressor to multivariate time series...
# 100%|██████████| 100/100 [04:06<00:00,  2.46s/it]
# Elapsed: 249.10436272621155
